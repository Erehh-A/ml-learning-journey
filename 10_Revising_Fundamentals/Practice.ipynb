# %% [markdown]
# ## NumPy

# %%
import numpy as np
a = np.array([12, 42, 34])
st = np.array(["Helloo", "Bye"])
# a.dtype
st.dtype
# Out:
# dtype('<U6')

# %%
st.shape
# Out:
# (2,)

# %%
st.reshape(2, 1)
# print(st)
# Out:
# array([['Helloo'],
#        ['Bye']], dtype='<U6')

# %%
st.shape
# Out:
# (2,)

# %% [markdown]
# ### np.mean(X, axis=0)  # column-wise
# ### np.mean(X, axis=1)  # row-wise
