# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_toy.csv')
df.sample(5)
# Out:
#       Age     Fare  Family  Survived
# 28    NaN   7.8792       0         1
# 294  24.0   7.8958       0         0
# 226  19.0  10.5000       0         1
# 349  42.0   8.6625       0         0
# 828   NaN   7.7500       0         1

# %%
# df.isnull().sum()
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

x_train.shape, x_test.shape
# Out:
# ((712, 3), (179, 3))

# %%
plt.hist(x_train['Age'], edgecolor='black')
# Out:
# (array([ 38.,  25.,  92., 127., 109.,  72.,  44.,  28.,  21.,   8.]),
#  array([ 0.42 ,  7.478, 14.536, 21.594, 28.652, 35.71 , 42.768, 49.826,
#         56.884, 63.942, 71.   ]),
#  <BarContainer object of 10 artists>)

# %%
x_train.isnull().mean()
# Out:
# Age       0.207865
# Fare      0.050562
# Family    0.000000
# dtype: float64

# %% [markdown]
# ### Using sklearn

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1', imputer1, ['Age']),
    ('imputer2', imputer2, ['Fare'])
], remainder='passthrough')

# %%
trf.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([28.75])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([32.61759689])

# %%
x_train = trf.transform(x_train)
x_test = trf.transform(x_test)
# print(x_train)

# %%
plt.hist(x_train[:, 0], edgecolor='black')
# Out:
# (array([ 38.,  25.,  92., 127., 257.,  72.,  44.,  28.,  21.,   8.]),
#  array([ 0.42 ,  7.478, 14.536, 21.594, 28.652, 35.71 , 42.768, 49.826,
#         56.884, 63.942, 71.   ]),
#  <BarContainer object of 10 artists>)
