# %% [markdown]
# ### Analyzing a single column at a time

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv('anime.csv')
# df.shape

# %%
# df.head()
df.sample(5)
# Out:
#        anime_id                              name  \
# 7916        788  Eiken: Eikenbu yori Ai wo Komete
# 10570     29473                 Toko-chan Chokkin
# 10588     30135        Topo Gigio no Botan Sensou
# 12157      5423              Mogitate Marina-chan
# 2332        395                   Gantz 2nd Stage
#
#                                                    genre   type episodes  \
# 7916                        Comedy, Ecchi, Harem, School    OVA        2
# 10570         Adventure, Historical, Kids, Slice of Life     TV        3
# 10588                                   Historical, Kids  Movie        1
# 12157                                             Hentai    OVA        1
# 2332   Action, Drama, Horror, Psychological, Sci-Fi, ...     TV       13
#
#        rating  members
# 7916     4.65    15764
# 10570    6.67       37
# 10588    5.00       52
# 12157    5.43      268
# 2332     7.29    87240

# %% [markdown]
# ### Categorical Data
# count plot, pie plot

# %% [markdown]
# ### Numerical Data

# %%
sns.histplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df['rating'].max()
# Out:
#        anime_id                                     name            genre  \
# 10400     30120              Spoon-hime no Swing Kitchen  Adventure, Kids
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files   Comedy, Parody
#
#         type episodes  rating  members
# 10400     TV  Unknown     9.6       47
# 10464  Movie        1    10.0       13
