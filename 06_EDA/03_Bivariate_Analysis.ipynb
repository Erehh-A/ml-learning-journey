# %% [markdown]
# ### Bivariate and Multivariate Analysis - Analysis on multiple columns at a time

# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

titanic = pd.read_csv('Titanic.csv')
tips = sns.load_dataset('tips')
