# %%
import pandas as pd 
df = pd.read_csv('train.csv')

# %% [markdown]
# ### 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 2. How does the data look like?

# %%
# df.head(5)     Top 5 rows
df.sample(5)   # Random 5 rows
# Out:
#      PassengerId  Survived  Pclass  \
# 677          678         1       3
# 625          626         0       1
# 558          559         1       1
# 871          872         1       1
# 464          465         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 677                           Turja, Miss. Anna Sofia  female  18.0      0
# 625                             Sutton, Mr. Frederick    male  61.0      0
# 558            Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 464                                Maisner, Mr. Simon    male   NaN      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 677      0      4138   9.8417   NaN        S
# 625      0     36963  32.3208   D50        S
# 558      1    110413  79.6500   E67        S
# 871      1     11751  52.5542   D35        S
# 464      0  A/S 2816   8.0500   NaN        S

# %% [markdown]
# ### 3. What is the data type of columns?

# %%
df.info()
# Can change the data types of unecessary data types to reduce the overall size (eg. here age is in float64 we can change that into int)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ### 4. Are there any missing values?

# %%
# As we can see above there r some missing values in AGE, CABIN and EMBARKED so to get them in a seperate table
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 6. Are there duplicate values?

# %%
df.duplicated().sum()
# If there is any duplicate values, we can remove that using drop duplicate function from pandas
# Out:
# np.int64(0)

# %% [markdown]
# ### 7. How is the correlation between cols?

# %%
nums_columns = ["PassengerId", "Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"]
df[nums_columns].corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000
